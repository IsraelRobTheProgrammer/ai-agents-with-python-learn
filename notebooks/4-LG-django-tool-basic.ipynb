# %%
import setup

setup.init()

# %%
from ai.tools import list_documents, get_document

config = {"user_id": 2}

# %%
list_documents.invoke("")
# Out:
# {'tags': [], 'metadata': {}, 'callbacks': None, 'recursion_limit': 25, 'configurable': {}}
# {} cinfnfnfnf
# <class 'dict'>
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 list_documents.invoke("")
#
# File ~/Documents/AI_ML/ai_agents_with_python/.venv/lib/python3.10/site-packages/langchain_core/tools/base.py:642, in BaseTool.invoke(self, input, config, **kwargs)
#     634 @override
#     635 def invoke(
#     636     self,
#    (...)
#     639     **kwargs: Any,
#     640 ) -> Any:
#     641     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 642     return self.run(tool_input, **kwargs)
#
# ...

# %%
get_document.invoke({"doc_id": 1}, config)
# Out:
# {'user_id': 2} cinfnfnfnf
# <class 'dict'>
# Document matching query does not exist. error from Doesn't exist
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# File ~/Documents/AI_ML/ai_agents_with_python/src/ai/tools.py:56, in get_document(doc_id, config)
#      55 try:
# ---> 56     doc_obj = Document.objects.get(id=doc_id, active=True, owner_id=user_id)
#      57 except Document.DoesNotExist as e:
#
# File ~/Documents/AI_ML/ai_agents_with_python/.venv/lib/python3.10/site-packages/django/db/models/manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# ...
