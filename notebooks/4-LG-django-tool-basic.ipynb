# %%
import setup

setup.init()

# %%
from ai.tools import list_documents, get_document

config = {"user_id": 2}

# %%
list_documents.invoke("", config)
# Out:
# {'tags': [], 'metadata': {'user_id': 2}, 'callbacks': None, 'recursion_limit': 25, 'configurable': {'user_id': 2}}
# [{'id': 2, 'title': 'Hello world Doc'}]

# %%
get_document.invoke({"doc_id": 2}, config)
# Out:
# <Document: Hello world Doc>
# {'id': 2,
#  'title': 'Hello world Doc',
#  'content': 'SOme content for hello world',
#  'created_at': datetime.datetime(2026, 2, 21, 19, 28, 11, 862515, tzinfo=datetime.timezone.utc)}
