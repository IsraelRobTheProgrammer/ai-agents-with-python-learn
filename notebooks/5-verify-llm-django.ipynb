# %%
import setup

setup.init()

# %%
from ai.llms import get_required_model

model = get_required_model(
    metadata={"provider": "Google", "model": "gemini-2.0-flash"},
)

# %%
model.invoke("Who are you?")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/Documents/AI_ML/ai_agents_with_python/.venv/lib/python3.10/site-packages/langchain_google_genai/chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#
# File ~/Documents/AI_ML/ai_agents_with_python/.venv/lib/python3.10/site-packages/google/genai/models.py:5621, in Models.generate_content(self, model, contents, config)
#    5620 i += 1
# -> 5621 response = self._generate_content(
#    5622     model=model, contents=contents, config=parsed_config
#    5623 )
# ...

# %%
AIMessage(
    content="I’m ChatGPT, a large language model created by OpenAI, built on the GPT-4 architecture. I’m here to help with questions, writing and editing, explanations, brainstorming, coding, and more.\n\nA few basics:\n- I don’t know who you are unless you tell me in this chat, and I don’t retain personal data between conversations unless you choose to share it.\n- I don’t have real-time internet access unless a browsing tool is enabled.\n- My knowledge goes up to around mid-2024, so I may not have the latest events or updates.\n\nHow can I assist you today?",
    additional_kwargs={"refusal": None},
    response_metadata={
        "token_usage": {
            "completion_tokens": 838,
            "prompt_tokens": 10,
            "total_tokens": 848,
            "completion_tokens_details": {
                "accepted_prediction_tokens": 0,
                "audio_tokens": 0,
                "reasoning_tokens": 704,
                "rejected_prediction_tokens": 0,
            },
            "prompt_tokens_details": {"audio_tokens": 0, "cached_tokens": 0},
        },
        "model_provider": "openai",
        "model_name": "gpt-5-nano-2025-08-07",
        "system_fingerprint": None,
        "id": "chatcmpl-DDpHz6OkNGTCvVOYcdNGHmTm5u4ik",
        "service_tier": "default",
        "finish_reason": "stop",
        "logprobs": None,
    },
    id="lc_run--019c9e9f-aa05-7953-9022-dd96e011b521-0",
    tool_calls=[],
    invalid_tool_calls=[],
    usage_metadata={
        "input_tokens": 10,
        "output_tokens": 838,
        "total_tokens": 848,
        "input_token_details": {"audio": 0, "cache_read": 0},
        "output_token_details": {"audio": 0, "reasoning": 704},
    },
)
