# %%
import setup

setup.init()

# %%
from django.contrib.auth import get_user_model

User = get_user_model()

User.objects.all()
# Out:
# <QuerySet [<User: admin>, <User: staff>]>

# %%
# new_user_obj = User(username="staff")

# staff_user_obj = User.objects.get(username="staff")
# print(staff_user_obj)
staff_user_obj.set_password("tech_geek_123")
staff_user_obj.save()

# %%
# User.objects.create(username="tech_geek", is_staff=True)
tech_geek_obj = User.objects.get(username="tech_geek")

tech_geek_obj.set_password("tech_geek_123")
tech_geek_obj.save()

# %%
# from document_manager.models import Document

# new_doc_obj = Document(
#     owner = staff_user_obj,
#     title="Hello world Doc"
# )

# new_doc_obj.save()
new_doc_obj
# Out:
# <Document: <Document: Hello world Doc>>
